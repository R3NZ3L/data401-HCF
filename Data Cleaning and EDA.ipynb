# %% [markdown]
# # **Import**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Reading datasets**

# %%
# Reading population per barangay dataset
ppb_df = pd.read_csv('Datasets/population_per_barangay.csv')
ppb_df.head()
# Out:
#    New 10 digit PSGC  New 10 PCODE                    Region     Reg_Code  \
# 0          102801001  PH0102801001  Region I (Ilocos Region)  PH010000000
# 1          102802001  PH0102802001  Region I (Ilocos Region)  PH010000000
# 2          102802002  PH0102802002  Region I (Ilocos Region)  PH010000000
# 3          102802003  PH0102802003  Region I (Ilocos Region)  PH010000000
# 4          102802004  PH0102802004  Region I (Ilocos Region)  PH010000000
#
#        Province    Prov_Code Mun_City     Mun_Code    Barangay     Bgy_Code  \
# 0  Ilocos Norte  PH012800000    Adams  PH012801000       Adams  PH012801001
# 1  Ilocos Norte  PH012800000  Bacarra  PH012802000        Bani  PH012802001
# 2  Ilocos Norte  PH012800000  Bacarra  PH012802000       Buyon  PH012802002
# 3  Ilocos Norte  PH012800000  Bacarra  PH012802000    Cabaruan  PH012802003
# 4  Ilocos Norte  PH012800000  Bacarra  PH012802000  Cabulalaan  PH012802004
#
#   Bgy_Old names Urban / Rural\n(based on 2020 CPH)  2020 Census Popn
# 0           NaN                                  R            2189.0
# 1           NaN                                  R            1079.0
# 2           NaN                                  R            1669.0
# 3           NaN                                  R            1418.0
# 4           NaN                                  R             733.0

# %%
hf_df = pd.read_csv('Datasets/health_facilities.csv')
hf_df.sort_values(by=['region'], inplace=True)
hf_df.head()
# Out:
#           id          facilityco                           healthfaci  \
# 1398  1452.0  DOH000000000031732       Bangco Barangay Health Station
# 1515  1569.0  DOH000000000014693  Katutungan Barangay Health  Station
# 1514  1568.0  DOH000000000014687  Pagalungan Barangay Health  Station
# 1513  1567.0  DOH000000000014690      Milaya Barangay Health  Station
# 1512  1566.0  DOH000000000014684  Kabatangan Barangay Health  Station
#
#                    typeofheal           barangay             municipali  \
# 1398  Barangay Health Station             Bangco  Marawi City (capital)
# 1515  Barangay Health Station  Katutungan (Pob.)                    Wao
# 1514  Barangay Health Station         Pagalongan                    Wao
# 1513  Barangay Health Station             Milaya                    Wao
# 1512  Barangay Health Station         Kabatangan                    Wao
#
#            province                                             region status  \
# 1398  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1515  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1514  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1513  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1512  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
#
#      address                    style
# 1398     NaN  Barangay Health Station
# 1515     NaN  Barangay Health Station
# 1514     NaN  Barangay Health Station
# 1513     NaN  Barangay Health Station
# 1512     NaN  Barangay Health Station

# %% [markdown]
# # **Cleaning/Preprocessing**

# %% [markdown]
# **Rename provinces**
# > Maguindanao del Norte -> ***Maguindanao***
#
# > Maguindanao del Sur -> ***Maguindanao***
#
# > City of Isabela (Not a Province) -> ***City of Isabela***
#
# > First District (Not a Province) -> ***First District***
#
# > Second District (Not a Province) -> ***Second District***
#
# > Third District (Not a Province) -> ***Third District***
#
# > Fourth District (Not a Province) -> ***Fourth District***

# %%
# Dictionary for region name correction (have it inline with the rest of the datasets)
PPN_correction = {
    "Maguindanao del Norte": "Maguindanao",
    "Maguindanao del Sur": "Maguindanao",
    "City of Isabela (Not a Province)": "City of Isabela",
    "First District (Not a Province)": "First District",
    "Second District (Not a Province)": "Second District",
    "Third District (Not a Province)": "Third District",
    "Fourth District (Not a Province)": "Fourth District",
}


for old_province, new_province in PPN_correction.items():
    ppb_df.loc[ppb_df['Province'] == old_province, 'Province'] = new_province

# %% [markdown]
# > ## **Population per barangay**

# %% [markdown]
# ---
# Making the <i>population_per_municipality.csv</i> dataset from the <i>population_per_barangay.csv</i> dataset

# %%
# Array of unique municipality names
muni_names = np.array(ppb_df['Mun_City'].unique())

# Array of unique region names
region_names = np.array(ppb_df['Region'].unique())

print("Number of municipalities found: " + str(ppb_df['Mun_City'].nunique()))
# Out:
# Number of municipalities found: 1422

# %%
# Aggregating by municipality and adding each barangay's population
ppm_df = ppb_df.groupby(['Region', 'Reg_Code', 'Province', 'Prov_Code', 'Mun_City', 'Mun_Code'], as_index=False).sum()

print("Number of municipalities after groupby: " + str(ppm_df['Mun_City'].nunique()))

ppm_df.sort_values(by=['Mun_Code'], inplace=True)
ppm_df.drop(columns=['New 10 digit PSGC'], inplace=True)
ppm_df.head()
# Out:
# Number of municipalities after groupby: 1422
# <ipython-input-6-4cbc51e2729e>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ppm_df = ppb_df.groupby(['Region', 'Reg_Code', 'Province', 'Prov_Code', 'Mun_City', 'Mun_Code'], as_index=False).sum()
#                        Region     Reg_Code      Province    Prov_Code  \
# 286  Region I (Ilocos Region)  PH010000000  Ilocos Norte  PH012800000
# 287  Region I (Ilocos Region)  PH010000000  Ilocos Norte  PH012800000
# 288  Region I (Ilocos Region)  PH010000000  Ilocos Norte  PH012800000
# 293  Region I (Ilocos Region)  PH010000000  Ilocos Norte  PH012800000
# 289  Region I (Ilocos Region)  PH010000000  Ilocos Norte  PH012800000
#
#           Mun_City     Mun_Code  2020 Census Popn
# 286          Adams  PH012801000            2189.0
# 287        Bacarra  PH012802000           33496.0
# 288          Badoc  PH012803000           32530.0
# 293  City of Batac  PH012804000           55484.0
# 289         Bangui  PH012804000           15019.0

# %%
# Export to .csv
ppm_df.to_csv('Datasets/population_per_municipality.csv')

# %%
# If true, then the number of municipalities are consistent between the two Dataframes
ppb_df['Mun_City'].nunique() == ppm_df['Mun_City'].nunique()
# Out:
# True

# %% [markdown]
# > ## **Population per province**

# %% [markdown]
# ---
# Making <i>population_per_province.csv</i>

# %%
ppp_df = ppm_df.groupby(['Region', 'Reg_Code', 'Province', 'Prov_Code'], as_index=False).sum()

# Create a new row to add to the DataFrame
new_row = {'Region': "Region XII (SOCCSKSARGEN)", 'Reg_Code': "PH120000000", 'Province': "Cotabato City", 'Prov_Code': "PH129800000", '2020 Census Popn': 325079.0}

# Append the new row to the DataFrame
ppp_df = ppp_df.append(new_row, ignore_index=True)

ppp_df.sort_values(by=['Province'], inplace=True)
ppp_df.head(30)
# Out:
# <ipython-input-9-bbf19e72b088>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ppp_df = ppm_df.groupby(['Region', 'Reg_Code', 'Province', 'Prov_Code'], as_index=False).sum()
# <ipython-input-9-bbf19e72b088>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ppp_df = ppp_df.append(new_row, ignore_index=True)
#                                                Region     Reg_Code  \
# 5              Cordillera Administrative Region (CAR)  PH140000000
# 81                               Region XIII (Caraga)  PH160000000
# 82                               Region XIII (Caraga)  PH160000000
# 51                        Region VI (Western Visayas)  PH060000000
# 45                            Region V (Bicol Region)  PH050000000
# 52                        Region VI (Western Visayas)  PH060000000
# 6              Cordillera Administrative Region (CAR)  PH140000000
# 29                         Region III (Central Luzon)  PH030000000
# 0   Bangsamoro Autonomous Region In Muslim Mindana...  PH150000000
# 30                         Region III (Central Luzon)  PH030000000
# 24                         Region II (Cagayan Valley)  PH020000000
# 36                           Region IV-A (CALABARZON)  PH040000000
# 7              Cordillera Administrative Region (CAR)  PH140000000
# 61                      Region VIII (Eastern Visayas)  PH080000000
# 57                       Region VII (Central Visayas)  PH070000000
# 67                       Region X (Northern Mindanao)  PH100000000
# 31                         Region III (Central Luzon)  PH030000000
# 25                         Region II (Cagayan Valley)  PH020000000
# 46                            Region V (Bicol Region)  PH050000000
# 47                            Region V (Bicol Region)  PH050000000
# 68                       Region X (Northern Mindanao)  PH100000000
# 53                        Region VI (Western Visayas)  PH060000000
# 48                            Region V (Bicol Region)  PH050000000
# 37                           Region IV-A (CALABARZON)  PH040000000
# 58                       Region VII (Central Visayas)  PH070000000
# 41                    Region IX (Zamboanga Peninsula)  PH090000000
# 77                          Region XII (SOCCSKSARGEN)  PH120000000
# 86                          Region XII (SOCCSKSARGEN)  PH120000000
# 72                           Region XI (Davao Region)  PH110000000
# 73                           Region XI (Davao Region)  PH110000000
#
#             Province    Prov_Code  2020 Census Popn
# 5               Abra  PH140100000          250985.0
# 81  Agusan del Norte  PH160200000          760413.0
# 82    Agusan del Sur  PH160300000          739367.0
# 51             Aklan  PH060400000          615475.0
# 45             Albay  PH050500000         1374768.0
# 52           Antique  PH060600000          612974.0
# 6             Apayao  PH148100000          124366.0
# 29            Aurora  PH037700000          235750.0
# 0            Basilan  PH150700000          426207.0
# 30            Bataan  PH030800000          853373.0
# 24           Batanes  PH020900000           18831.0
# 36          Batangas  PH041000000         2908494.0
# 7            Benguet  PH141100000          827041.0
# 61           Biliran  PH087800000          179312.0
# 57             Bohol  PH071200000         1394329.0
# 67          Bukidnon  PH101300000         1541308.0
# 31           Bulacan  PH031400000         3708890.0
# 25           Cagayan  PH021500000         1268603.0
# 46   Camarines Norte  PH051600000          629699.0
# 47     Camarines Sur  PH051700000         2068244.0
# 68          Camiguin  PH101800000           92808.0
# 53             Capiz  PH061900000          804952.0
# 48       Catanduanes  PH052000000          271879.0
# 37            Cavite  PH042100000         4344829.0
# 58              Cebu  PH072200000         5151274.0
# 41   City of Isabela  PH099700000          130379.0
# 77          Cotabato  PH124700000         1275185.0
# 86     Cotabato City  PH129800000          325079.0
# 72  Davao Occidental  PH118600000          317159.0
# 73    Davao Oriental  PH112500000          576343.0

# %%
specific_row = ppp_df[ppp_df['Province'] == "Cotabato City"]

specific_row
# Out:
#                        Region     Reg_Code       Province    Prov_Code  \
# 86  Region XII (SOCCSKSARGEN)  PH120000000  Cotabato City  PH129800000
#
#     2020 Census Popn
# 86          325079.0

# %%
# Export to .csv
ppp_df.to_csv('Datasets/population_per_province.csv')

# %% [markdown]
# ---
# Finding unique province names

# %%
provinces = ppp_df['Province'].unique()
provinces.sort()
for province in provinces:
    print(province)
print('---')
print('Number of provinces: ' + str(ppp_df['Province'].nunique()))
# Out:
# Abra
# Agusan del Norte
# Agusan del Sur
# Aklan
# Albay
# Antique
# Apayao
# Aurora
# Basilan
# Bataan
# Batanes
# Batangas
# Benguet
# Biliran
# Bohol
# Bukidnon
# Bulacan
# Cagayan
# Camarines Norte
# Camarines Sur
# Camiguin
# Capiz
# Catanduanes
# Cavite
# Cebu
# City of Isabela
# Cotabato
# Cotabato City
# Davao Occidental
# Davao Oriental
# Davao de Oro
# Davao del Norte
# Davao del Sur
# Dinagat Islands
# Eastern Samar
# First District
# Fourth District
# Guimaras
# Ifugao
# Ilocos Norte
# Ilocos Sur
# Iloilo
# Isabela
# Kalinga
# La Union
# Laguna
# Lanao del Norte
# Lanao del Sur
# Leyte
# Maguindanao
# Marinduque
# Masbate
# Misamis Occidental
# Misamis Oriental
# Mountain Province
# Negros Occidental
# Negros Oriental
# Northern Samar
# Nueva Ecija
# Nueva Vizcaya
# Occidental Mindoro
# Oriental Mindoro
# Palawan
# Pampanga
# Pangasinan
# Quezon
# Quirino
# Rizal
# Romblon
# Samar
# Sarangani
# Second District
# Siquijor
# Sorsogon
# South Cotabato
# Southern Leyte
# Sultan Kudarat
# Sulu
# Surigao del Norte
# Surigao del Sur
# Tarlac
# Tawi-Tawi
# Third District
# Zambales
# Zamboanga Sibugay
# Zamboanga del Norte
# Zamboanga del Sur
# ---
# Number of provinces: 87

# %%
ppp_df.loc[ppp_df['Province'] == 'Maguindanao del Norte']
# Out:
# Empty DataFrame
# Columns: [Region, Reg_Code, Province, Prov_Code, 2020 Census Popn]
# Index: []

# %%
ppp_df.loc[ppp_df['Province'] == 'Maguindanao del Sur']
# Out:
# Empty DataFrame
# Columns: [Region, Reg_Code, Province, Prov_Code, 2020 Census Popn]
# Index: []

# %% [markdown]
# > ## **Population per region**

# %% [markdown]
# ---
# Making <i>population_per_region.csv</i>

# %%
ppr_df = ppp_df.groupby(['Region', 'Reg_Code'], as_index=False).sum()
ppr_df.sort_values(by=['Reg_Code'], inplace=True)
ppr_df.head(20)
# Out:
# <ipython-input-15-316fdcf824a3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ppr_df = ppp_df.groupby(['Region', 'Reg_Code'], as_index=False).sum()
#                                                Region     Reg_Code  \
# 4                            Region I (Ilocos Region)  PH010000000
# 5                          Region II (Cagayan Valley)  PH020000000
# 6                          Region III (Central Luzon)  PH030000000
# 7                            Region IV-A (CALABARZON)  PH040000000
# 9                             Region V (Bicol Region)  PH050000000
# 10                        Region VI (Western Visayas)  PH060000000
# 11                       Region VII (Central Visayas)  PH070000000
# 12                      Region VIII (Eastern Visayas)  PH080000000
# 8                     Region IX (Zamboanga Peninsula)  PH090000000
# 13                       Region X (Northern Mindanao)  PH100000000
# 14                           Region XI (Davao Region)  PH110000000
# 15                          Region XII (SOCCSKSARGEN)  PH120000000
# 3                       National Capital Region (NCR)  PH130000000
# 1              Cordillera Administrative Region (CAR)  PH140000000
# 0   Bangsamoro Autonomous Region In Muslim Mindana...  PH150000000
# 16                               Region XIII (Caraga)  PH160000000
# 2                                     MIMAROPA Region  PH170000000
#
#     2020 Census Popn
# 4          5301139.0
# 5          3685744.0
# 6         12422172.0
# 7         16195042.0
# 9          6082165.0
# 10         7954723.0
# 11         8081988.0
# 12         4547150.0
# 8          3875576.0
# 13         5022768.0
# 14         5243536.0
# 15         4686053.0
# 3         13484462.0
# 1          1797660.0
# 0          4729367.0
# 16         2804788.0
# 2          3228558.0

# %%
# Export to .csv
ppr_df.to_csv('Datasets/population_per_region.csv')

# %% [markdown]
# ---
# Finding unique region names

# %%
regions = ppr_df['Region'].unique()
regions.sort()
for region in regions:
    print(region)
print('---')
print('Number of regions: ' + str(ppr_df['Region'].nunique()))
# Out:
# Bangsamoro Autonomous Region In Muslim Mindanao (BARMM)
# Cordillera Administrative Region (CAR)
# MIMAROPA Region
# National Capital Region (NCR)
# Region I (Ilocos Region)
# Region II (Cagayan Valley)
# Region III (Central Luzon)
# Region IV-A (CALABARZON)
# Region IX (Zamboanga Peninsula)
# Region V (Bicol Region)
# Region VI (Western Visayas)
# Region VII (Central Visayas)
# Region VIII (Eastern Visayas)
# Region X (Northern Mindanao)
# Region XI (Davao Region)
# Region XII (SOCCSKSARGEN)
# Region XIII (Caraga)
# ---
# Number of regions: 17

# %% [markdown]
# > ## **Health Facilities**

# %% [markdown]
# ---
# Exploring the <i>region</i> column of the <i>health_facilities</i> dataset

# %%
hf_df.head()
# Out:
#           id          facilityco                           healthfaci  \
# 1398  1452.0  DOH000000000031732       Bangco Barangay Health Station
# 1515  1569.0  DOH000000000014693  Katutungan Barangay Health  Station
# 1514  1568.0  DOH000000000014687  Pagalungan Barangay Health  Station
# 1513  1567.0  DOH000000000014690      Milaya Barangay Health  Station
# 1512  1566.0  DOH000000000014684  Kabatangan Barangay Health  Station
#
#                    typeofheal           barangay             municipali  \
# 1398  Barangay Health Station             Bangco  Marawi City (capital)
# 1515  Barangay Health Station  Katutungan (Pob.)                    Wao
# 1514  Barangay Health Station         Pagalongan                    Wao
# 1513  Barangay Health Station             Milaya                    Wao
# 1512  Barangay Health Station         Kabatangan                    Wao
#
#            province                                             region status  \
# 1398  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1515  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1514  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1513  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1512  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
#
#      address                    style
# 1398     NaN  Barangay Health Station
# 1515     NaN  Barangay Health Station
# 1514     NaN  Barangay Health Station
# 1513     NaN  Barangay Health Station
# 1512     NaN  Barangay Health Station

# %% [markdown]
# Rename column 'region' and 'province'

# %%
hf_df.rename(columns={'region': 'Region'}, inplace=True)
hf_df.rename(columns={'province': 'Province'}, inplace=True)\

hf_df.head()
# Out:
#           id          facilityco                           healthfaci  \
# 1398  1452.0  DOH000000000031732       Bangco Barangay Health Station
# 1515  1569.0  DOH000000000014693  Katutungan Barangay Health  Station
# 1514  1568.0  DOH000000000014687  Pagalungan Barangay Health  Station
# 1513  1567.0  DOH000000000014690      Milaya Barangay Health  Station
# 1512  1566.0  DOH000000000014684  Kabatangan Barangay Health  Station
#
#                    typeofheal           barangay             municipali  \
# 1398  Barangay Health Station             Bangco  Marawi City (capital)
# 1515  Barangay Health Station  Katutungan (Pob.)                    Wao
# 1514  Barangay Health Station         Pagalongan                    Wao
# 1513  Barangay Health Station             Milaya                    Wao
# 1512  Barangay Health Station         Kabatangan                    Wao
#
#            Province                                             Region status  \
# 1398  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1515  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1514  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1513  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
# 1512  Lanao Del Sur  Bangsamoro Autonomous Region In Muslim Mindana...    NaN
#
#      address                    style
# 1398     NaN  Barangay Health Station
# 1515     NaN  Barangay Health Station
# 1514     NaN  Barangay Health Station
# 1513     NaN  Barangay Health Station
# 1512     NaN  Barangay Health Station

# %% [markdown]
# Filtering 'style' to
#
# * Barangay Health Stations
# * Hospital
# * Medical Clinic
# * Rural Health Unit

# %%
hf_df = pd.DataFrame(hf_df)

# Specify the categories you want to filter
chosen_type = ['Barangay Health Station', 'Hospital', 'Medical Clinic', 'Rural Health Unit']

# Filter rows based on the specified categories
hf_df = hf_df[hf_df['style'].isin(chosen_type)]

# %% [markdown]
# Unique ***regions***

# %%
hf_df_RNs_original = hf_df['Region'].unique()
hf_df_RNs_original.sort()
for name in hf_df_RNs_original:
    print(name)
# Out:
# Bangsamoro Autonomous Region In Muslim Mindanao (BARMM)
# CAR (CORDILLERA ADMINISTRATIVE REGION
# NCR (NATIONAL CAPITAL REGION)
# REGION I (ILOCOS REGION)
# REGION II (CAGAYAN VALLEY)
# REGION III (CENTRAL LUZON)
# REGION IV-A (CALABARZON)
# REGION IV-B (MIMAROPA)
# REGION IX (ZAMBOANGA PENINSULA)
# REGION V (BICOL REGION)
# REGION VI (WESTERN VISAYAS)
# REGION VII (CENTRAL VISAYAS)
# REGION VIII (EASTERN VISAYAS)
# REGION XI (DAVAO REGION)
# REGION XII (SOCCSKSARGEN)
# REGION XIII (CARAGA)
# Region X (northern Mindanao)

# %% [markdown]
# Unique ***provinces***

# %%
hf_df_RNs_original = hf_df['Province'].unique()
hf_df_RNs_original.sort()
for name in hf_df_RNs_original:
    print(name)
# Out:
# ABRA
# AGUSAN DEL NORTE
# AGUSAN DEL SUR
# AKLAN
# ALBAY
# ANTIQUE
# APAYAO
# AURORA
# BATAAN
# BATANES
# BATANGAS
# BENGUET
# BILIRAN
# BOHOL
# BULACAN
# Basilan
# Bukidnon
# CAGAYAN
# CAMARINES NORTE
# CAMARINES SUR
# CAPIZ
# CATANDUANES
# CAVITE
# CEBU
# COMPOSTELA VALLEY
# Camiguin
# City Of Isabela (not A Province)
# Cotabato (North Cotabato)
# Cotabato City (Not a Province)
# DAVAO DEL NORTE
# DAVAO DEL SUR
# DAVAO OCCIDENTAL
# DAVAO ORIENTAL
# DINAGAT ISLANDS
# EASTERN SAMAR
# GUIMARAS
# IFUGAO
# ILOCOS NORTE
# ILOCOS SUR
# ILOILO
# ISABELA
# KALINGA
# LA UNION
# LAGUNA
# LEYTE
# Lanao Del Norte
# Lanao Del Sur
# MARINDUQUE
# MASBATE
# MOUNTAIN PROVINCE
# Maguindanao
# Misamis Occidental
# Misamis Oriental
# NCR
# NCR, CITY OF MANILA, FIRST DISTRICT
# NCR, FOURTH DISTRICT
# NCR, SECOND DISTRICT
# NCR, THIRD DISTRICT
# NEGROS OCCIDENTAL
# NEGROS ORIENTAL
# NORTHERN SAMAR
# NUEVA ECIJA
# NUEVA VIZCAYA
# OCCIDENTAL MINDORO
# ORIENTAL MINDORO
# PALAWAN
# PAMPANGA
# PANGASINAN
# QUEZON
# QUIRINO
# RIZAL
# ROMBLON
# SAMAR (WESTERN SAMAR)
# SIQUIJOR
# SORSOGON
# SOUTHERN LEYTE
# SURIGAO DEL NORTE
# SURIGAO DEL SUR
# Sarangani
# South Cotabato
# Sultan Kudarat
# Sulu
# TARLAC
# Tawi -tawi
# ZAMBALES
# Zamboanga Del Norte
# Zamboanga Del Sur
# Zamboanga Sibugay

# %% [markdown]
# > #### **Rename region and province names**

# %% [markdown]
# **Region**

# %%
# Dictionary for region name correction (have it inline with the rest of the datasets)
RN_correction = {
    "Bangsamoro Autonomous Region In Muslim Mindanao (BARMM)": "Bangsamoro Autonomous Region In Muslim Mindanao (BARMM)",
    "CAR (CORDILLERA ADMINISTRATIVE REGION": "Cordillera Administrative Region (CAR)",
    "NCR (NATIONAL CAPITAL REGION)": "National Capital Region (NCR)",
    "REGION I (ILOCOS REGION)": "Region I (Ilocos Region)",
    "REGION II (CAGAYAN VALLEY)": "Region II (Cagayan Valley)",
    "REGION III (CENTRAL LUZON)": "Region III (Central Luzon)",
    "REGION IV-A (CALABARZON)": "Region IV-A (CALABARZON)",
    "REGION IV-B (MIMAROPA)": "MIMAROPA Region",
    "REGION IX (ZAMBOANGA PENINSULA)": "Region IX (Zamboanga Peninsula)",
    "REGION V (BICOL REGION)": "Region V (Bicol Region)",
    "REGION VI (WESTERN VISAYAS)": "Region VI (Western Visayas)",
    "REGION VII (CENTRAL VISAYAS)": "Region VII (Central Visayas)",
    "REGION VIII (EASTERN VISAYAS)": "Region VIII (Eastern Visayas)",
    "REGION XI (DAVAO REGION)": "Region XI (Davao Region)",
    "REGION XII (SOCCSKSARGEN)": "Region XII (SOCCSKSARGEN)",
    "REGION XIII (CARAGA)": "Region XIII (Caraga)",
    "Region X (northern Mindanao)": "Region X (Northern Mindanao)"
}


for old_region, new_region in RN_correction.items():
    hf_df.loc[hf_df['Region'] == old_region, 'Region'] = new_region

# %% [markdown]
# **Province**

# %%
PN_correction = {
    "ABRA": "Abra",
    "AGUSAN DEL NORTE": "Agusan del Norte",
    "AGUSAN DEL SUR": "Agusan del Sur",
    "AKLAN": "Aklan",
    "ALBAY": "Albay",
    "ANTIQUE": "Antique",
    "APAYAO": "Apayao",
    "AURORA": "Aurora",
    "BATAAN": "Bataan",
    "BATANES": "Batanes",
    "BATANGAS": "Batangas",
    "BENGUET": "Benguet",
    "BILIRAN": "Biliran",
    "BOHOL": "Bohol",
    "BULACAN": "Bulacan",
    "Basilan": "Basilan",
    "Bukidnon": "Bukidnon",
    "CAGAYAN": "Cagayan",
    "CAMARINES NORTE": "Camarines Norte",
    "CAMARINES SUR": "Camarines Sur",
    "Camiguin": "Camiguin",
    "CAPIZ": "Capiz",
    "CATANDUANES": "Catanduanes",
    "CAVITE": "Cavite",
    "CEBU": "Cebu",
    "City Of Isabela (not A Province)": "City of Isabela",
    "COMPOSTELA VALLEY": "Davao de Oro",
    "Cotabato (North Cotabato)": "Cotabato",
    "Cotabato City (Not a Province)": "Cotabato City",
    "DAVAO DEL NORTE": "Davao del Norte",
    "DAVAO DEL SUR": "Davao del Sur",
    "DAVAO OCCIDENTAL": "Davao Occidental",
    "DAVAO ORIENTAL": "Davao Oriental",
    "DINAGAT ISLANDS": "Dinagat Islands",
    "EASTERN SAMAR": "Eastern Samar",
    "GUIMARAS": "Guimaras",
    "IFUGAO": "Ifugao",
    "ILOCOS NORTE": "Ilocos Norte",
    "ILOCOS SUR": "Ilocos Sur",
    "ILOILO": "Iloilo",
    "ISABELA": "Isabela",
    "KALINGA": "Kalinga",
    "LA UNION": "La Union",
    "LAGUNA": "Laguna",
    "LEYTE": "Leyte",
    "Lanao Del Norte": "Lanao del Norte",
    "Lanao Del Sur": "Lanao del Sur",
    "MARINDUQUE": "Marinduque",
    "MASBATE": "Masbate",
    "MOUNTAIN PROVINCE": "Mountain Province",
    "Maguindanao": "Maguindanao",
    "Misamis Occidental": "Misamis Occidental",
    "Misamis Oriental": "Misamis Oriental",
    "NCR": "Second District",
    "NCR, CITY OF MANILA, FIRST DISTRICT": "First District",
    "NCR, FOURTH DISTRICT": "Fourth District",
    "NCR, SECOND DISTRICT": "Second District",
    "NCR, THIRD DISTRICT": "Third District",
    "NEGROS OCCIDENTAL": "Negros Occidental",
    "NEGROS ORIENTAL": "Negros Oriental",
    "NORTHERN SAMAR": "Northern Samar",
    "NUEVA ECIJA": "Nueva Ecija",
    "NUEVA VIZCAYA": "Nueva Vizcaya",
    "OCCIDENTAL MINDORO": "Occidental Mindoro",
    "ORIENTAL MINDORO": "Oriental Mindoro",
    "PALAWAN": "Palawan",
    "PAMPANGA": "Pampanga",
    "PANGASINAN": "Pangasinan",
    "QUEZON": "Quezon",
    "QUIRINO": "Quirino",
    "RIZAL": "Rizal",
    "ROMBLON": "Romblon",
    "SAMAR (WESTERN SAMAR)": "Samar",
    "SIQUIJOR": "Siquijor",
    "SORSOGON": "Sorsogon",
    "SOUTHERN LEYTE": "Southern Leyte",
    "SURIGAO DEL NORTE": "Surigao del Norte",
    "SURIGAO DEL SUR": "Surigao del Sur",
    "Sarangani": "Sarangani",
    "South Cotabato": "South Cotabato",
    "Sultan Kudarat": "Sultan Kudarat",
    "Sulu": "Sulu",
    "TARLAC": "Tarlac",
    "Tawi -tawi": "Tawi-Tawi",
    "ZAMBALES": "Zambales",
    "Zamboanga Del Norte": "Zamboanga del Norte",
    "Zamboanga Del Sur": "Zamboanga del Sur",
    "Zamboanga Sibugay": "Zamboanga Sibugay",
}

for old_province, new_province in PN_correction.items():
    hf_df.loc[hf_df['Province'] == old_province, 'Province'] = new_province

# %% [markdown]
# Check if renaming is successful

# %%
# region

hf_df_RNs_original = hf_df['Region'].unique()
hf_df_RNs_original.sort()
for name in hf_df_RNs_original:
    print(name)
# Out:
# Bangsamoro Autonomous Region In Muslim Mindanao (BARMM)
# Cordillera Administrative Region (CAR)
# MIMAROPA Region
# National Capital Region (NCR)
# Region I (Ilocos Region)
# Region II (Cagayan Valley)
# Region III (Central Luzon)
# Region IV-A (CALABARZON)
# Region IX (Zamboanga Peninsula)
# Region V (Bicol Region)
# Region VI (Western Visayas)
# Region VII (Central Visayas)
# Region VIII (Eastern Visayas)
# Region X (Northern Mindanao)
# Region XI (Davao Region)
# Region XII (SOCCSKSARGEN)
# Region XIII (Caraga)

# %%
# province

hf_df_PNs_original = hf_df['Province'].unique()
hf_df_PNs_original.sort()
for name in hf_df_PNs_original:
    print(name)
# Out:
# Abra
# Agusan del Norte
# Agusan del Sur
# Aklan
# Albay
# Antique
# Apayao
# Aurora
# Basilan
# Bataan
# Batanes
# Batangas
# Benguet
# Biliran
# Bohol
# Bukidnon
# Bulacan
# Cagayan
# Camarines Norte
# Camarines Sur
# Camiguin
# Capiz
# Catanduanes
# Cavite
# Cebu
# City of Isabela
# Cotabato
# Cotabato City
# Davao Occidental
# Davao Oriental
# Davao de Oro
# Davao del Norte
# Davao del Sur
# Dinagat Islands
# Eastern Samar
# First District
# Fourth District
# Guimaras
# Ifugao
# Ilocos Norte
# Ilocos Sur
# Iloilo
# Isabela
# Kalinga
# La Union
# Laguna
# Lanao del Norte
# Lanao del Sur
# Leyte
# Maguindanao
# Marinduque
# Masbate
# Misamis Occidental
# Misamis Oriental
# Mountain Province
# Negros Occidental
# Negros Oriental
# Northern Samar
# Nueva Ecija
# Nueva Vizcaya
# Occidental Mindoro
# Oriental Mindoro
# Palawan
# Pampanga
# Pangasinan
# Quezon
# Quirino
# Rizal
# Romblon
# Samar
# Sarangani
# Second District
# Siquijor
# Sorsogon
# South Cotabato
# Southern Leyte
# Sultan Kudarat
# Sulu
# Surigao del Norte
# Surigao del Sur
# Tarlac
# Tawi-Tawi
# Third District
# Zambales
# Zamboanga Sibugay
# Zamboanga del Norte
# Zamboanga del Sur

# %% [markdown]
# > ### **Per province**

# %% [markdown]
# Get style count per province

# %%
hf_df_p = hf_df[['Province', 'style']]
hf_df_p['style_count_per_province'] = hf_df_p.groupby(['Province', 'style'])['style'].transform('count')
hf_df_p = pd.DataFrame(hf_df_p)

hf_df_p.head(20)
# Out:
# <ipython-input-27-cac8f958dab4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hf_df_p['style_count_per_province'] = hf_df_p.groupby(['Province', 'style'])['style'].transform('count')
#            Province                    style  style_count_per_province
# 1398  Lanao del Sur  Barangay Health Station                       112
# 1515  Lanao del Sur  Barangay Health Station                       112
# 1514  Lanao del Sur  Barangay Health Station                       112
# 1513  Lanao del Sur  Barangay Health Station                       112
# 1512  Lanao del Sur  Barangay Health Station                       112
# 1510  Lanao del Sur  Barangay Health Station                       112
# 1509  Lanao del Sur  Barangay Health Station                       112
# 1508  Lanao del Sur                 Hospital                        16
# 1516  Lanao del Sur  Barangay Health Station                       112
# 1502  Lanao del Sur        Rural Health Unit                        43
# 1498  Lanao del Sur  Barangay Health Station                       112
# 1497  Lanao del Sur        Rural Health Unit                        43
# 1496  Lanao del Sur        Rural Health Unit                        43
# 1495  Lanao del Sur        Rural Health Unit                        43
# 1494  Lanao del Sur        Rural Health Unit                        43
# 1493  Lanao del Sur        Rural Health Unit                        43
# 1492  Lanao del Sur  Barangay Health Station                       112
# 1491  Lanao del Sur        Rural Health Unit                        43
# 1490  Lanao del Sur  Barangay Health Station                       112
# 1489  Lanao del Sur  Barangay Health Station                       112

# %%
hf_df_p = hf_df_p.groupby(['Province', 'style', 'style_count_per_province'], as_index=False).sum()
hf_df_p.sort_values(by=['Province'], inplace=True)
hf_df_p.head(20)
# Out:
#             Province                    style  style_count_per_province
# 0               Abra  Barangay Health Station                       110
# 1               Abra                 Hospital                         6
# 2               Abra           Medical Clinic                         1
# 3               Abra        Rural Health Unit                        23
# 4   Agusan del Norte  Barangay Health Station                       213
# 5   Agusan del Norte                 Hospital                        12
# 6   Agusan del Norte        Rural Health Unit                        16
# 7     Agusan del Sur  Barangay Health Station                       134
# 8     Agusan del Sur                 Hospital                        15
# 9     Agusan del Sur        Rural Health Unit                        12
# 10             Aklan  Barangay Health Station                       126
# 11             Aklan                 Hospital                        13
# 12             Aklan        Rural Health Unit                        25
# 15             Albay           Medical Clinic                         2
# 16             Albay        Rural Health Unit                        18
# 13             Albay  Barangay Health Station                       179
# 14             Albay                 Hospital                        35
# 17           Antique  Barangay Health Station                       137
# 18           Antique                 Hospital                        12
# 19           Antique        Rural Health Unit                        18

# %% [markdown]
# Reformat table, having styles as columns

# %%
# Pivot the DataFrame
hf_df_p = hf_df_p.pivot_table(index='Province', columns='style', values='style_count_per_province', aggfunc='sum', fill_value=0)

# Reset the index to make 'province' a regular column
hf_df_p.reset_index(inplace=True)

# Display the resulting pivoted DataFrame
hf_df_p.head(100)
# Out:
# style             Province  Barangay Health Station  Hospital  Medical Clinic  \
# 0                     Abra                      110         6               1
# 1         Agusan del Norte                      213        12               0
# 2           Agusan del Sur                      134        15               0
# 3                    Aklan                      126        13               0
# 4                    Albay                      179        35               2
# ..                     ...                      ...       ...             ...
# 82          Third District                       49        28               1
# 83                Zambales                      220        16               0
# 84       Zamboanga Sibugay                      125         6               0
# 85     Zamboanga del Norte                      370         5               0
# 86       Zamboanga del Sur                      380        23               0
#
# style  Rural Health Unit
# 0                     23
# 1                     16
# 2                     12
# 3                     25
# 4                     18
# ..                   ...
# 82                    78
# 83                    16
# 84                    16
# 85                    28
# 86                    45
#
# [87 rows x 5 columns]

# %% [markdown]
# Get total Health Care Facilities (***total_HCF***)

# %%
hf_df_p['total_HCF'] = hf_df_p[['Barangay Health Station', 'Hospital', 'Medical Clinic', 'Rural Health Unit']].sum(axis=1)
hf_df_p.head(100)
# Out:
# style             Province  Barangay Health Station  Hospital  Medical Clinic  \
# 0                     Abra                      110         6               1
# 1         Agusan del Norte                      213        12               0
# 2           Agusan del Sur                      134        15               0
# 3                    Aklan                      126        13               0
# 4                    Albay                      179        35               2
# ..                     ...                      ...       ...             ...
# 82          Third District                       49        28               1
# 83                Zambales                      220        16               0
# 84       Zamboanga Sibugay                      125         6               0
# 85     Zamboanga del Norte                      370         5               0
# 86       Zamboanga del Sur                      380        23               0
#
# style  Rural Health Unit  total_HCF
# 0                     23        140
# 1                     16        241
# 2                     12        161
# 3                     25        164
# 4                     18        234
# ..                   ...        ...
# 82                    78        156
# 83                    16        252
# 84                    16        147
# 85                    28        403
# 86                    45        448
#
# [87 rows x 6 columns]

# %% [markdown]
# > ### **Per region**

# %% [markdown]
# Get style count per region

# %%
hf_df_r = hf_df[['Region', 'style']]
hf_df_r['style_count_per_region'] = hf_df_r.groupby(['Region', 'style'])['style'].transform('count')
hf_df_r = pd.DataFrame(hf_df_r)

hf_df_r.head(20)
# Out:
# <ipython-input-31-9caacc3f1ee3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hf_df_r['style_count_per_region'] = hf_df_r.groupby(['Region', 'style'])['style'].transform('count')
#                                                  Region  \
# 1398  Bangsamoro Autonomous Region In Muslim Mindana...
# 1515  Bangsamoro Autonomous Region In Muslim Mindana...
# 1514  Bangsamoro Autonomous Region In Muslim Mindana...
# 1513  Bangsamoro Autonomous Region In Muslim Mindana...
# 1512  Bangsamoro Autonomous Region In Muslim Mindana...
# 1510  Bangsamoro Autonomous Region In Muslim Mindana...
# 1509  Bangsamoro Autonomous Region In Muslim Mindana...
# 1508  Bangsamoro Autonomous Region In Muslim Mindana...
# 1516  Bangsamoro Autonomous Region In Muslim Mindana...
# 1502  Bangsamoro Autonomous Region In Muslim Mindana...
# 1498  Bangsamoro Autonomous Region In Muslim Mindana...
# 1497  Bangsamoro Autonomous Region In Muslim Mindana...
# 1496  Bangsamoro Autonomous Region In Muslim Mindana...
# 1495  Bangsamoro Autonomous Region In Muslim Mindana...
# 1494  Bangsamoro Autonomous Region In Muslim Mindana...
# 1493  Bangsamoro Autonomous Region In Muslim Mindana...
# 1492  Bangsamoro Autonomous Region In Muslim Mindana...
# 1491  Bangsamoro Autonomous Region In Muslim Mindana...
# 1490  Bangsamoro Autonomous Region In Muslim Mindana...
# 1489  Bangsamoro Autonomous Region In Muslim Mindana...
#
#                         style  style_count_per_region
# 1398  Barangay Health Station                     595
# 1515  Barangay Health Station                     595
# 1514  Barangay Health Station                     595
# 1513  Barangay Health Station                     595
# 1512  Barangay Health Station                     595
# 1510  Barangay Health Station                     595
# 1509  Barangay Health Station                     595
# 1508                 Hospital                      44
# 1516  Barangay Health Station                     595
# 1502        Rural Health Unit                     123
# 1498  Barangay Health Station                     595
# 1497        Rural Health Unit                     123
# 1496        Rural Health Unit                     123
# 1495        Rural Health Unit                     123
# 1494        Rural Health Unit                     123
# 1493        Rural Health Unit                     123
# 1492  Barangay Health Station                     595
# 1491        Rural Health Unit                     123
# 1490  Barangay Health Station                     595
# 1489  Barangay Health Station                     595

# %%
hf_df_r = hf_df_r.groupby(['Region', 'style', 'style_count_per_region'], as_index=False).sum()
hf_df_r.sort_values(by=['Region'], inplace=True)
hf_df_r.head(20)
# Out:
#                                                Region  \
# 0   Bangsamoro Autonomous Region In Muslim Mindana...
# 1   Bangsamoro Autonomous Region In Muslim Mindana...
# 2   Bangsamoro Autonomous Region In Muslim Mindana...
# 3              Cordillera Administrative Region (CAR)
# 4              Cordillera Administrative Region (CAR)
# 5              Cordillera Administrative Region (CAR)
# 6              Cordillera Administrative Region (CAR)
# 10                                    MIMAROPA Region
# 9                                     MIMAROPA Region
# 8                                     MIMAROPA Region
# 7                                     MIMAROPA Region
# 11                      National Capital Region (NCR)
# 12                      National Capital Region (NCR)
# 13                      National Capital Region (NCR)
# 14                      National Capital Region (NCR)
# 18                           Region I (Ilocos Region)
# 17                           Region I (Ilocos Region)
# 15                           Region I (Ilocos Region)
# 16                           Region I (Ilocos Region)
# 19                         Region II (Cagayan Valley)
#
#                       style  style_count_per_region
# 0   Barangay Health Station                     595
# 1                  Hospital                      44
# 2         Rural Health Unit                     123
# 3   Barangay Health Station                     785
# 4                  Hospital                      53
# 5            Medical Clinic                       2
# 6         Rural Health Unit                      88
# 10        Rural Health Unit                      79
# 9            Medical Clinic                       4
# 8                  Hospital                      65
# 7   Barangay Health Station                    1074
# 11  Barangay Health Station                     133
# 12                 Hospital                     186
# 13           Medical Clinic                       5
# 14        Rural Health Unit                     373
# 18        Rural Health Unit                     157
# 17           Medical Clinic                       8
# 15  Barangay Health Station                    1210
# 16                 Hospital                     122
# 19  Barangay Health Station                    1189

# %% [markdown]
# Reformat table, having styles as columns

# %%
# Pivot the DataFrame
hf_df_r = hf_df_r.pivot_table(index='Region', columns='style', values='style_count_per_region', aggfunc='sum', fill_value=0)

# Reset the index to make 'region' a regular column
hf_df_r.reset_index(inplace=True)

# Display the resulting pivoted DataFrame
hf_df_r.head(100)
# Out:
# style                                             Region  \
# 0      Bangsamoro Autonomous Region In Muslim Mindana...
# 1                 Cordillera Administrative Region (CAR)
# 2                                        MIMAROPA Region
# 3                          National Capital Region (NCR)
# 4                               Region I (Ilocos Region)
# 5                             Region II (Cagayan Valley)
# 6                             Region III (Central Luzon)
# 7                               Region IV-A (CALABARZON)
# 8                        Region IX (Zamboanga Peninsula)
# 9                                Region V (Bicol Region)
# 10                           Region VI (Western Visayas)
# 11                          Region VII (Central Visayas)
# 12                         Region VIII (Eastern Visayas)
# 13                          Region X (Northern Mindanao)
# 14                              Region XI (Davao Region)
# 15                             Region XII (SOCCSKSARGEN)
# 16                                  Region XIII (Caraga)
#
# style  Barangay Health Station  Hospital  Medical Clinic  Rural Health Unit
# 0                          595        44               0                123
# 1                          785        53               2                 88
# 2                         1074        65               4                 79
# 3                          133       186               5                373
# 4                         1210       122               8                157
# 5                         1189        96               5                 94
# 6                         1880       205               9                267
# 7                         2409       268               7                198
# 8                          899        37               0                 92
# 9                         1150       111               9                135
# 10                        1775        93               2                146
# 11                        1818        95               2                152
# 12                         764        82               3                159
# 13                        1257        75               0                129
# 14                         998       107               6                 62
# 15                        1168        64               0                104
# 16                         814        58               1                 82

# %% [markdown]
# Get total Health Care Facilities (***total_HCF***)

# %%
hf_df_r['total_HCF'] = hf_df_r[['Barangay Health Station', 'Hospital', 'Medical Clinic', 'Rural Health Unit']].sum(axis=1)
hf_df_r.head(100)
# Out:
# style                                             Region  \
# 0      Bangsamoro Autonomous Region In Muslim Mindana...
# 1                 Cordillera Administrative Region (CAR)
# 2                                        MIMAROPA Region
# 3                          National Capital Region (NCR)
# 4                               Region I (Ilocos Region)
# 5                             Region II (Cagayan Valley)
# 6                             Region III (Central Luzon)
# 7                               Region IV-A (CALABARZON)
# 8                        Region IX (Zamboanga Peninsula)
# 9                                Region V (Bicol Region)
# 10                           Region VI (Western Visayas)
# 11                          Region VII (Central Visayas)
# 12                         Region VIII (Eastern Visayas)
# 13                          Region X (Northern Mindanao)
# 14                              Region XI (Davao Region)
# 15                             Region XII (SOCCSKSARGEN)
# 16                                  Region XIII (Caraga)
#
# style  Barangay Health Station  Hospital  Medical Clinic  Rural Health Unit  \
# 0                          595        44               0                123
# 1                          785        53               2                 88
# 2                         1074        65               4                 79
# 3                          133       186               5                373
# 4                         1210       122               8                157
# 5                         1189        96               5                 94
# 6                         1880       205               9                267
# 7                         2409       268               7                198
# 8                          899        37               0                 92
# 9                         1150       111               9                135
# 10                        1775        93               2                146
# 11                        1818        95               2                152
# 12                         764        82               3                159
# 13                        1257        75               0                129
# 14                         998       107               6                 62
# 15                        1168        64               0                104
# 16                         814        58               1                 82
#
# style  total_HCF
# 0            762
# 1            928
# 2           1222
# 3            697
# 4           1497
# 5           1384
# 6           2361
# 7           2882
# 8           1028
# 9           1405
# 10          2016
# 11          2067
# 12          1008
# 13          1461
# 14          1173
# 15          1336
# 16           955

# %% [markdown]
# #**Unedited population files**

# %%
region_df = pd.read_csv('Datasets/population_per_region.csv')
region_df.head()
# Out:
#    Unnamed: 0                      Region     Reg_Code  2020 Census Popn
# 0           4    Region I (Ilocos Region)  PH010000000         5301139.0
# 1           5  Region II (Cagayan Valley)  PH020000000         3685744.0
# 2           6  Region III (Central Luzon)  PH030000000        12422172.0
# 3           7    Region IV-A (CALABARZON)  PH040000000        16195042.0
# 4           9     Region V (Bicol Region)  PH050000000         6082165.0

# %%
region_df["2020 Census Popn"].sum()
# Out:
# 109142891.0

# %%
province_df = pd.read_csv('Datasets/population_per_province.csv')
province_df.head()
# Out:
#    Unnamed: 0                                  Region     Reg_Code  \
# 0           5  Cordillera Administrative Region (CAR)  PH140000000
# 1          81                    Region XIII (Caraga)  PH160000000
# 2          82                    Region XIII (Caraga)  PH160000000
# 3          51             Region VI (Western Visayas)  PH060000000
# 4          45                 Region V (Bicol Region)  PH050000000
#
#            Province    Prov_Code  2020 Census Popn
# 0              Abra  PH140100000          250985.0
# 1  Agusan del Norte  PH160200000          760413.0
# 2    Agusan del Sur  PH160300000          739367.0
# 3             Aklan  PH060400000          615475.0
# 4             Albay  PH050500000         1374768.0

# %%
province_df["2020 Census Popn"].sum()
# Out:
# 109142891.0

# %% [markdown]
# # **Joined layers (as CSV)**
# This is to check if the populations align across maps. Per region, per province, and per municipality populations must have the same total).

# %%
new_province_df = pd.read_csv('Datasets/new_population_per_province.csv')
new_province_df.head()
# Out:
#         ADM2_EN   ADM2_PCODE    ADM1_EN   ADM1_PCODE            ADM0_EN  \
# 0  Ilocos Norte  PH012800000   Region I  PH010000000  Philippines (the)
# 1    Ilocos Sur  PH012900000   Region I  PH010000000  Philippines (the)
# 2      La Union  PH013300000   Region I  PH010000000  Philippines (the)
# 3    Pangasinan  PH015500000   Region I  PH010000000  Philippines (the)
# 4       Batanes  PH020900000  Region II  PH020000000  Philippines (the)
#
#   ADM0_PCODE  2020 Censu
# 0         PH    609588.0
# 1         PH    706009.0
# 2         PH    822352.0
# 3         PH   3163190.0
# 4         PH     18831.0

# %%
new_provinces = new_province_df['ADM2_EN'].unique()
new_provinces.sort()
for new_province in new_provinces:
    print(new_province)
print('---')
print('Number of provinces: ' + str(new_province_df['ADM2_EN'].nunique()))
# Out:
# Abra
# Agusan del Norte
# Agusan del Sur
# Aklan
# Albay
# Antique
# Apayao
# Aurora
# Basilan
# Bataan
# Batanes
# Batangas
# Benguet
# Biliran
# Bohol
# Bukidnon
# Bulacan
# Cagayan
# Camarines Norte
# Camarines Sur
# Camiguin
# Capiz
# Catanduanes
# Cavite
# Cebu
# City of Isabela
# Compostela Valley
# Cotabato
# Cotabato City
# Davao Occidental
# Davao Oriental
# Davao del Norte
# Davao del Sur
# Dinagat Islands
# Eastern Samar
# Guimaras
# Ifugao
# Ilocos Norte
# Ilocos Sur
# Iloilo
# Isabela
# Kalinga
# La Union
# Laguna
# Lanao del Norte
# Lanao del Sur
# Leyte
# Maguindanao
# Marinduque
# Masbate
# Misamis Occidental
# Misamis Oriental
# Mountain Province
# NCR, City of Manila, First District
# NCR, Fourth District
# NCR, Second District
# NCR, Third District
# Negros Occidental
# Negros Oriental
# Northern Samar
# Nueva Ecija
# Nueva Vizcaya
# Occidental Mindoro
# Oriental Mindoro
# Palawan
# Pampanga
# Pangasinan
# Quezon
# Quirino
# Rizal
# Romblon
# Samar
# Sarangani
# Siquijor
# Sorsogon
# South Cotabato
# Southern Leyte
# Sultan Kudarat
# Sulu
# Surigao del Norte
# Surigao del Sur
# Tarlac
# Tawi-Tawi
# Zambales
# Zamboanga Sibugay
# Zamboanga del Norte
# Zamboanga del Sur
# ---
# Number of provinces: 87

# %%
specific_row = new_province_df[new_province_df['ADM2_EN'] == "Cotabato City"]

specific_row
# Out:
#           ADM2_EN   ADM2_PCODE     ADM1_EN   ADM1_PCODE            ADM0_EN  \
# 61  Cotabato City  PH129800000  Region XII  PH120000000  Philippines (the)
#
#    ADM0_PCODE  2020 Censu
# 61         PH    325079.0

# %%
new_region_df = pd.read_csv('Datasets/new_population_per_region.csv')
new_region_df.head()
# Out:
#        ADM1_EN   ADM1_PCODE            ADM0_EN ADM0_PCODE  field_1  \
# 0     Region I  PH010000000  Philippines (the)         PH        4
# 1    Region II  PH020000000  Philippines (the)         PH        5
# 2   Region III  PH030000000  Philippines (the)         PH        6
# 3  Region IV-A  PH040000000  Philippines (the)         PH        7
# 4     Region V  PH050000000  Philippines (the)         PH        9
#
#                        Region     Reg_Code  2020 Censu
# 0    Region I (Ilocos Region)  PH010000000   5301139.0
# 1  Region II (Cagayan Valley)  PH020000000   3685744.0
# 2  Region III (Central Luzon)  PH030000000  12422172.0
# 3    Region IV-A (CALABARZON)  PH040000000  16195042.0
# 4     Region V (Bicol Region)  PH050000000   6082165.0

# %%
new_province_df.columns

new_province_df.head()
# Out:
#         ADM2_EN   ADM2_PCODE    ADM1_EN   ADM1_PCODE            ADM0_EN  \
# 0  Ilocos Norte  PH012800000   Region I  PH010000000  Philippines (the)
# 1    Ilocos Sur  PH012900000   Region I  PH010000000  Philippines (the)
# 2      La Union  PH013300000   Region I  PH010000000  Philippines (the)
# 3    Pangasinan  PH015500000   Region I  PH010000000  Philippines (the)
# 4       Batanes  PH020900000  Region II  PH020000000  Philippines (the)
#
#   ADM0_PCODE  2020 Censu
# 0         PH    609588.0
# 1         PH    706009.0
# 2         PH    822352.0
# 3         PH   3163190.0
# 4         PH     18831.0

# %%
province_popn = new_province_df["2020 Censu"].sum()
region_popn = new_region_df["2020 Censu"].sum()

print(province_popn - region_popn)
# Out:
# 0.0

# %% [markdown]
# # **Merge (HCF and Population) in preparation for analysis**

# %% [markdown]
# ## **Per province**

# %%
merged_p = pd.merge(ppp_df, hf_df_p, on='Province')

# %%
merged_p.head(30)
# Out:
#                                                Region     Reg_Code  \
# 0              Cordillera Administrative Region (CAR)  PH140000000
# 1                                Region XIII (Caraga)  PH160000000
# 2                                Region XIII (Caraga)  PH160000000
# 3                         Region VI (Western Visayas)  PH060000000
# 4                             Region V (Bicol Region)  PH050000000
# 5                         Region VI (Western Visayas)  PH060000000
# 6              Cordillera Administrative Region (CAR)  PH140000000
# 7                          Region III (Central Luzon)  PH030000000
# 8   Bangsamoro Autonomous Region In Muslim Mindana...  PH150000000
# 9                          Region III (Central Luzon)  PH030000000
# 10                         Region II (Cagayan Valley)  PH020000000
# 11                           Region IV-A (CALABARZON)  PH040000000
# 12             Cordillera Administrative Region (CAR)  PH140000000
# 13                      Region VIII (Eastern Visayas)  PH080000000
# 14                       Region VII (Central Visayas)  PH070000000
# 15                       Region X (Northern Mindanao)  PH100000000
# 16                         Region III (Central Luzon)  PH030000000
# 17                         Region II (Cagayan Valley)  PH020000000
# 18                            Region V (Bicol Region)  PH050000000
# 19                            Region V (Bicol Region)  PH050000000
# 20                       Region X (Northern Mindanao)  PH100000000
# 21                        Region VI (Western Visayas)  PH060000000
# 22                            Region V (Bicol Region)  PH050000000
# 23                           Region IV-A (CALABARZON)  PH040000000
# 24                       Region VII (Central Visayas)  PH070000000
# 25                    Region IX (Zamboanga Peninsula)  PH090000000
# 26                          Region XII (SOCCSKSARGEN)  PH120000000
# 27                          Region XII (SOCCSKSARGEN)  PH120000000
# 28                           Region XI (Davao Region)  PH110000000
# 29                           Region XI (Davao Region)  PH110000000
#
#             Province    Prov_Code  2020 Census Popn  Barangay Health Station  \
# 0               Abra  PH140100000          250985.0                      110
# 1   Agusan del Norte  PH160200000          760413.0                      213
# 2     Agusan del Sur  PH160300000          739367.0                      134
# 3              Aklan  PH060400000          615475.0                      126
# 4              Albay  PH050500000         1374768.0                      179
# 5            Antique  PH060600000          612974.0                      137
# 6             Apayao  PH148100000          124366.0                      114
# 7             Aurora  PH037700000          235750.0                      108
# 8            Basilan  PH150700000          426207.0                      130
# 9             Bataan  PH030800000          853373.0                      189
# 10           Batanes  PH020900000           18831.0                        7
# 11          Batangas  PH041000000         2908494.0                      586
# 12           Benguet  PH141100000          827041.0                      160
# 13           Biliran  PH087800000          179312.0                       35
# 14             Bohol  PH071200000         1394329.0                      468
# 15          Bukidnon  PH101300000         1541308.0                      418
# 16           Bulacan  PH031400000         3708890.0                      510
# 17           Cagayan  PH021500000         1268603.0                      312
# 18   Camarines Norte  PH051600000          629699.0                      129
# 19     Camarines Sur  PH051700000         2068244.0                      302
# 20          Camiguin  PH101800000           92808.0                       38
# 21             Capiz  PH061900000          804952.0                      310
# 22       Catanduanes  PH052000000          271879.0                       61
# 23            Cavite  PH042100000         4344829.0                      617
# 24              Cebu  PH072200000         5151274.0                      924
# 25   City of Isabela  PH099700000          130379.0                       24
# 26          Cotabato  PH124700000         1275185.0                      515
# 27     Cotabato City  PH129800000          325079.0                       40
# 28  Davao Occidental  PH118600000          317159.0                       59
# 29    Davao Oriental  PH112500000          576343.0                      196
#
#     Hospital  Medical Clinic  Rural Health Unit  total_HCF
# 0          6               1                 23        140
# 1         12               0                 16        241
# 2         15               0                 12        161
# 3         13               0                 25        164
# 4         35               2                 18        234
# 5         12               0                 18        167
# 6          7               1                  8        130
# 7          6               0                  8        122
# 8          4               0                 15        149
# 9         14               0                 20        223
# 10         2               0                  6         15
# 11        66               1                 49        702
# 12        16               0                 26        202
# 13         1               0                  9         45
# 14        27               0                 49        544
# 15        23               0                 28        469
# 16        77               2                 74        663
# 17        30               0                 31        373
# 18        11               1                 20        161
# 19        28               0                 45        375
# 20         1               0                  5         44
# 21        11               0                 16        337
# 22        11               0                 11         83
# 23        68               3                 34        722
# 24        53               1                 70       1048
# 25         3               0                  3         30
# 26        26               0                 31        572
# 27         6               0                  1         47
# 28         7               1                  5         72
# 29         6               0                 12        214

# %%
merged_pcode = merged_p[['Prov_Code', '2020 Census Popn', 'Barangay Health Station', 'Hospital', 'Medical Clinic', 'Rural Health Unit', 'total_HCF']]

merged_pcode
# Out:
#       Prov_Code  2020 Census Popn  Barangay Health Station  Hospital  \
# 0   PH140100000          250985.0                      110         6
# 1   PH160200000          760413.0                      213        12
# 2   PH160300000          739367.0                      134        15
# 3   PH060400000          615475.0                      126        13
# 4   PH050500000         1374768.0                      179        35
# ..          ...               ...                      ...       ...
# 82  PH137500000         3004627.0                       49        28
# 83  PH037100000          909932.0                      220        16
# 84  PH098300000          669840.0                      125         6
# 85  PH097200000         1047455.0                      370         5
# 86  PH097300000         2027902.0                      380        23
#
#     Medical Clinic  Rural Health Unit  total_HCF
# 0                1                 23        140
# 1                0                 16        241
# 2                0                 12        161
# 3                0                 25        164
# 4                2                 18        234
# ..             ...                ...        ...
# 82               1                 78        156
# 83               0                 16        252
# 84               0                 16        147
# 85               0                 28        403
# 86               0                 45        448
#
# [87 rows x 7 columns]

# %%
specific_row = merged_p[merged_p['Province'] == "Cotabato City"]

specific_row
# Out:
#                        Region     Reg_Code       Province    Prov_Code  \
# 27  Region XII (SOCCSKSARGEN)  PH120000000  Cotabato City  PH129800000
#
#     2020 Census Popn  Barangay Health Station  Hospital  Medical Clinic  \
# 27          325079.0                       40         6               0
#
#     Rural Health Unit  total_HCF
# 27                  1         47

# %% [markdown]
# Export csv

# %%
merged_p.to_csv('Datasets/merged_province.csv', index=False)
merged_pcode.to_csv('Datasets/merged_pcode.csv', index=False)

# %% [markdown]
# ## **Per region**

# %%
merged_r = pd.merge(ppr_df, hf_df_r, on='Region')

# %%
merged_r.head(30)
# Out:
#                                                Region     Reg_Code  \
# 0                            Region I (Ilocos Region)  PH010000000
# 1                          Region II (Cagayan Valley)  PH020000000
# 2                          Region III (Central Luzon)  PH030000000
# 3                            Region IV-A (CALABARZON)  PH040000000
# 4                             Region V (Bicol Region)  PH050000000
# 5                         Region VI (Western Visayas)  PH060000000
# 6                        Region VII (Central Visayas)  PH070000000
# 7                       Region VIII (Eastern Visayas)  PH080000000
# 8                     Region IX (Zamboanga Peninsula)  PH090000000
# 9                        Region X (Northern Mindanao)  PH100000000
# 10                           Region XI (Davao Region)  PH110000000
# 11                          Region XII (SOCCSKSARGEN)  PH120000000
# 12                      National Capital Region (NCR)  PH130000000
# 13             Cordillera Administrative Region (CAR)  PH140000000
# 14  Bangsamoro Autonomous Region In Muslim Mindana...  PH150000000
# 15                               Region XIII (Caraga)  PH160000000
# 16                                    MIMAROPA Region  PH170000000
#
#     2020 Census Popn  Barangay Health Station  Hospital  Medical Clinic  \
# 0          5301139.0                     1210       122               8
# 1          3685744.0                     1189        96               5
# 2         12422172.0                     1880       205               9
# 3         16195042.0                     2409       268               7
# 4          6082165.0                     1150       111               9
# 5          7954723.0                     1775        93               2
# 6          8081988.0                     1818        95               2
# 7          4547150.0                      764        82               3
# 8          3875576.0                      899        37               0
# 9          5022768.0                     1257        75               0
# 10         5243536.0                      998       107               6
# 11         4686053.0                     1168        64               0
# 12        13484462.0                      133       186               5
# 13         1797660.0                      785        53               2
# 14         4729367.0                      595        44               0
# 15         2804788.0                      814        58               1
# 16         3228558.0                     1074        65               4
#
#     Rural Health Unit  total_HCF
# 0                 157       1497
# 1                  94       1384
# 2                 267       2361
# 3                 198       2882
# 4                 135       1405
# 5                 146       2016
# 6                 152       2067
# 7                 159       1008
# 8                  92       1028
# 9                 129       1461
# 10                 62       1173
# 11                104       1336
# 12                373        697
# 13                 88        928
# 14                123        762
# 15                 82        955
# 16                 79       1222

# %%
merged_rcode = merged_r[['Reg_Code', '2020 Census Popn', 'Barangay Health Station', 'Hospital', 'Medical Clinic', 'Rural Health Unit', 'total_HCF']]

merged_rcode
# Out:
#        Reg_Code  2020 Census Popn  Barangay Health Station  Hospital  \
# 0   PH010000000         5301139.0                     1210       122
# 1   PH020000000         3685744.0                     1189        96
# 2   PH030000000        12422172.0                     1880       205
# 3   PH040000000        16195042.0                     2409       268
# 4   PH050000000         6082165.0                     1150       111
# 5   PH060000000         7954723.0                     1775        93
# 6   PH070000000         8081988.0                     1818        95
# 7   PH080000000         4547150.0                      764        82
# 8   PH090000000         3875576.0                      899        37
# 9   PH100000000         5022768.0                     1257        75
# 10  PH110000000         5243536.0                      998       107
# 11  PH120000000         4686053.0                     1168        64
# 12  PH130000000        13484462.0                      133       186
# 13  PH140000000         1797660.0                      785        53
# 14  PH150000000         4729367.0                      595        44
# 15  PH160000000         2804788.0                      814        58
# 16  PH170000000         3228558.0                     1074        65
#
#     Medical Clinic  Rural Health Unit  total_HCF
# 0                8                157       1497
# 1                5                 94       1384
# 2                9                267       2361
# 3                7                198       2882
# 4                9                135       1405
# 5                2                146       2016
# 6                2                152       2067
# 7                3                159       1008
# 8                0                 92       1028
# 9                0                129       1461
# 10               6                 62       1173
# 11               0                104       1336
# 12               5                373        697
# 13               2                 88        928
# 14               0                123        762
# 15               1                 82        955
# 16               4                 79       1222

# %% [markdown]
# Export csv

# %%
merged_r.to_csv('Datasets/merged_region.csv', index=False)
merged_rcode.to_csv('Datasets/merged_rcode.csv', index=False)

# %% [markdown]
#  ## **HCF per province (with PCODE)**

# %%
#merged_hcf_p = pd.merge(hf_df, merged_p, on='Province')

#merged_hcf_p = pd.merge(hf_df, merged_p, on='Province', how='inner')
merged_hcf_p = pd.merge(hf_df, merged_p, left_on='Province', right_on='Province', how='inner')


#hf_df['Prov_Code'] = merged_hcf_p['Prov_Code']

# %%
hf_df_pcode = merged_hcf_p[['id', 'facilityco', 'healthfaci', 'typeofheal', 'barangay', 'municipali', 'Province', 'Region_x', 'status', 'address', 'style', 'Prov_Code']]
hf_df_pcode.rename(columns={'Region_x': 'Region'}, inplace=True)
hf_df_pcode
# Out:
# <ipython-input-55-8fa9efd45f28>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hf_df_pcode.rename(columns={'Region_x': 'Region'}, inplace=True)
#            id          facilityco                           healthfaci  \
# 0      1452.0  DOH000000000031732       Bangco Barangay Health Station
# 1      1569.0  DOH000000000014693  Katutungan Barangay Health  Station
# 2      1568.0  DOH000000000014687  Pagalungan Barangay Health  Station
# 3      1567.0  DOH000000000014690      Milaya Barangay Health  Station
# 4      1566.0  DOH000000000014684  Kabatangan Barangay Health  Station
# ...       ...                 ...                                  ...
# 24177  3121.0  DOH000000000021846      Sinonoc Barangay Health Station
# 24178  3122.0  DOH000000000002197            Ozamiz City Health Office
# 24179  3123.0  DOH000000000021704       Aguada Barangay Health Station
# 24180  3124.0  DOH000000000021705     Banadero Barangay Health Station
# 24181  3114.0  DOH000000000021530       Tiaman Barangay Health Station
#
#                     typeofheal           barangay             municipali  \
# 0      Barangay Health Station             Bangco  Marawi City (capital)
# 1      Barangay Health Station  Katutungan (Pob.)                    Wao
# 2      Barangay Health Station         Pagalongan                    Wao
# 3      Barangay Health Station             Milaya                    Wao
# 4      Barangay Health Station         Kabatangan                    Wao
# ...                        ...                ...                    ...
# 24177  Barangay Health Station            Sinonoc              Sinacaban
# 24178        Rural Health Unit      Aguada (pob.)            Ozamis City
# 24179  Barangay Health Station      Aguada (pob.)            Ozamis City
# 24180  Barangay Health Station           Banadero            Ozamis City
# 24181  Barangay Health Station             Tiaman              Bonifacio
#
#                  Province                                             Region  \
# 0           Lanao del Sur  Bangsamoro Autonomous Region In Muslim Mindana...
# 1           Lanao del Sur  Bangsamoro Autonomous Region In Muslim Mindana...
# 2           Lanao del Sur  Bangsamoro Autonomous Region In Muslim Mindana...
# 3           Lanao del Sur  Bangsamoro Autonomous Region In Muslim Mindana...
# 4           Lanao del Sur  Bangsamoro Autonomous Region In Muslim Mindana...
# ...                   ...                                                ...
# 24177  Misamis Occidental                       Region X (Northern Mindanao)
# 24178  Misamis Occidental                       Region X (Northern Mindanao)
# 24179  Misamis Occidental                       Region X (Northern Mindanao)
# 24180  Misamis Occidental                       Region X (Northern Mindanao)
# 24181  Misamis Occidental                       Region X (Northern Mindanao)
#
#       status address                    style    Prov_Code
# 0        NaN     NaN  Barangay Health Station  PH153600000
# 1        NaN     NaN  Barangay Health Station  PH153600000
# 2        NaN     NaN  Barangay Health Station  PH153600000
# 3        NaN     NaN  Barangay Health Station  PH153600000
# 4        NaN     NaN  Barangay Health Station  PH153600000
# ...      ...     ...                      ...          ...
# 24177    NaN     NaN  Barangay Health Station  PH104200000
# 24178    NaN     NaN        Rural Health Unit  PH104200000
# 24179    NaN     NaN  Barangay Health Station  PH104200000
# 24180    NaN     NaN  Barangay Health Station  PH104200000
# 24181    NaN     NaN  Barangay Health Station  PH104200000
#
# [24182 rows x 12 columns]

# %% [markdown]
#  ## **HCF (with PCODE and RCODE)**

# %%
merged_hcf_r = pd.merge(hf_df_pcode, merged_r, left_on='Region', right_on='Region', how='inner')
merged_hcf_r
# Out:
#            id          facilityco                           healthfaci  \
# 0      1452.0  DOH000000000031732       Bangco Barangay Health Station
# 1      1569.0  DOH000000000014693  Katutungan Barangay Health  Station
# 2      1568.0  DOH000000000014687  Pagalungan Barangay Health  Station
# 3      1567.0  DOH000000000014690      Milaya Barangay Health  Station
# 4      1566.0  DOH000000000014684  Kabatangan Barangay Health  Station
# ...       ...                 ...                                  ...
# 24177  3121.0  DOH000000000021846      Sinonoc Barangay Health Station
# 24178  3122.0  DOH000000000002197            Ozamiz City Health Office
# 24179  3123.0  DOH000000000021704       Aguada Barangay Health Station
# 24180  3124.0  DOH000000000021705     Banadero Barangay Health Station
# 24181  3114.0  DOH000000000021530       Tiaman Barangay Health Station
#
#                     typeofheal           barangay             municipali  \
# 0      Barangay Health Station             Bangco  Marawi City (capital)
# 1      Barangay Health Station  Katutungan (Pob.)                    Wao
# 2      Barangay Health Station         Pagalongan                    Wao
# 3      Barangay Health Station             Milaya                    Wao
# 4      Barangay Health Station         Kabatangan                    Wao
# ...                        ...                ...                    ...
# 24177  Barangay Health Station            Sinonoc              Sinacaban
# 24178        Rural Health Unit      Aguada (pob.)            Ozamis City
# 24179  Barangay Health Station      Aguada (pob.)            Ozamis City
# 24180  Barangay Health Station           Banadero            Ozamis City
# 24181  Barangay Health Station             Tiaman              Bonifacio
#
#                  Province                                             Region  \
# 0           Lanao del Sur  Bangsamoro Autonomous Region In Muslim Mindana...
# 1           Lanao del Sur  Bangsamoro Autonomous Region In Muslim Mindana...
# 2           Lanao del Sur  Bangsamoro Autonomous Region In Muslim Mindana...
# 3           Lanao del Sur  Bangsamoro Autonomous Region In Muslim Mindana...
# 4           Lanao del Sur  Bangsamoro Autonomous Region In Muslim Mindana...
# ...                   ...                                                ...
# 24177  Misamis Occidental                       Region X (Northern Mindanao)
# 24178  Misamis Occidental                       Region X (Northern Mindanao)
# 24179  Misamis Occidental                       Region X (Northern Mindanao)
# 24180  Misamis Occidental                       Region X (Northern Mindanao)
# 24181  Misamis Occidental                       Region X (Northern Mindanao)
#
#       status address                    style    Prov_Code     Reg_Code  \
# 0        NaN     NaN  Barangay Health Station  PH153600000  PH150000000
# 1        NaN     NaN  Barangay Health Station  PH153600000  PH150000000
# 2        NaN     NaN  Barangay Health Station  PH153600000  PH150000000
# 3        NaN     NaN  Barangay Health Station  PH153600000  PH150000000
# 4        NaN     NaN  Barangay Health Station  PH153600000  PH150000000
# ...      ...     ...                      ...          ...          ...
# 24177    NaN     NaN  Barangay Health Station  PH104200000  PH100000000
# 24178    NaN     NaN        Rural Health Unit  PH104200000  PH100000000
# 24179    NaN     NaN  Barangay Health Station  PH104200000  PH100000000
# 24180    NaN     NaN  Barangay Health Station  PH104200000  PH100000000
# 24181    NaN     NaN  Barangay Health Station  PH104200000  PH100000000
#
#        2020 Census Popn  Barangay Health Station  Hospital  Medical Clinic  \
# 0             4729367.0                      595        44               0
# 1             4729367.0                      595        44               0
# 2             4729367.0                      595        44               0
# 3             4729367.0                      595        44               0
# 4             4729367.0                      595        44               0
# ...                 ...                      ...       ...             ...
# 24177         5022768.0                     1257        75               0
# 24178         5022768.0                     1257        75               0
# 24179         5022768.0                     1257        75               0
# 24180         5022768.0                     1257        75               0
# 24181         5022768.0                     1257        75               0
#
#        Rural Health Unit  total_HCF
# 0                    123        762
# 1                    123        762
# 2                    123        762
# 3                    123        762
# 4                    123        762
# ...                  ...        ...
# 24177                129       1461
# 24178                129       1461
# 24179                129       1461
# 24180                129       1461
# 24181                129       1461
#
# [24182 rows x 19 columns]

# %%
hf_df_prcode = merged_hcf_r[['id', 'Prov_Code', 'Reg_Code']]
hf_df_prcode
# Out:
#            id    Prov_Code     Reg_Code
# 0      1452.0  PH153600000  PH150000000
# 1      1569.0  PH153600000  PH150000000
# 2      1568.0  PH153600000  PH150000000
# 3      1567.0  PH153600000  PH150000000
# 4      1566.0  PH153600000  PH150000000
# ...       ...          ...          ...
# 24177  3121.0  PH104200000  PH100000000
# 24178  3122.0  PH104200000  PH100000000
# 24179  3123.0  PH104200000  PH100000000
# 24180  3124.0  PH104200000  PH100000000
# 24181  3114.0  PH104200000  PH100000000
#
# [24182 rows x 3 columns]

# %%
hf_df_prcode.to_csv('Datasets/hcf_prcode.csv', index=False)
